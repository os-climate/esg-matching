# %% [markdown]
# # How to...perform exact matching on Trino database

# %%
# Sets up the location of the api relative to this notebook 
import sys
sys.path.append('../../../')

# %%
# Import the module for connection to a sqllite database
from esg_matching.engine.connectors.trino import TrinoConnector

# %%
# Import the modules for file management
from esg_matching.file_reader.file import File
from esg_matching.file_reader.csv_reader import FileReaderCsv

# %%
# Import the modules for the etl processing: reading, transformation and loading data to a database
from esg_matching.processing.etl import EtlProcessing

# %% [markdown]
# ## 1. Database setup

# %%
import os
user_trino = os.environ['TRINO_USER']
pwd_trino = os.environ['TRINO_PASSWD']
host_trino = os.environ['TRINO_HOST']
port_trino = int(os.environ['TRINO_PORT'])

# %%
# The database connector is represented by the class TrinoConnector 
db_conn = TrinoConnector()

# %%
# The connect() method of the TrinoConnector is used to stablish a connection with the database if it exists, 
# or to create a new one. The property path_db defines the location and name of the database.
# The  property show_sql_statement indicates if the SQL statements are echoed (or printed) in the default output channel.
db_conn.username = user_trino
db_conn.user_password = pwd_trino
db_conn.host_url = host_trino
db_conn.port_number = port_trino
db_conn.catalog = 'osc_datacommons_iceberg_dev'
db_conn.show_sql_statement = True
db_conn.connect()
# Out:
# 2022-07-17 18:46:40,683 INFO sqlalchemy.engine.Engine SELECT version()
# 2022-07-17 18:46:40,686 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00304s] ()

# %%
# Check if the connection was stablished
db_conn.is_connected()
# Out:
# True

# %% [markdown]
# ## 2. Load the data into database from csv files

# %%
# Create an ETL process object
etl_proc_obj = EtlProcessing(db_conn)

# %%
# Crete a file reader object for csv files
csv_reader_obj = FileReaderCsv()

# %%
# Referential Data Source
ref_settings = '../../../tests/data/howto/trino/test_referential1_trino.json'
ref_obj = File(ref_settings)

# %%
# Load data from REFERENCIAL
db_ref = etl_proc_obj.load_file_to_db(ref_obj, csv_reader_obj)
# Out:
# 2022-07-17 18:46:45,097 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
# 2022-07-17 18:46:45,098 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00153s] ('esg_matching',)
# 2022-07-17 18:46:46,466 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
# 2022-07-17 18:46:46,467 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00121s] ('esg_matching',)
# 2022-07-17 18:46:47,847 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:46:47,848 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00105s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:46:49,017 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:46:49,018 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00112s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:46:50,385 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:46:50,386 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00097s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:46:51,483 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:46:51,484 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00070s] ('esg_matching', 'esg_match_tgt2$partitions')
# 2022-07-17 18:46:52,851 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_tgt2$properties"
# 2022-07-17 18:46:52,851 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00067s] ()
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'record_count' was not located in columns for table 'esg_match_tgt2'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'file_count' was not located in columns for table 'esg_match_tgt2'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'total_size' was not located in columns for table 'esg_match_tgt2'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'data' was not located in columns for table 'esg_match_tgt2'
#   metadata.reflect(self._engine)
# 2022-07-17 18:46:53,146 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:46:53,147 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:46:53,148 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00068s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:46:54,326 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:46:54,326 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00068s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:46:55,705 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:46:55,706 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00152s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:46:56,915 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:46:56,916 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00117s] ('esg_matching', 'esg_match_tgt1$partitions')
# 2022-07-17 18:46:58,303 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_tgt1$properties"
# 2022-07-17 18:46:58,304 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00128s] ()
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'record_count' was not located in columns for table 'esg_match_tgt1'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'file_count' was not located in columns for table 'esg_match_tgt1'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'total_size' was not located in columns for table 'esg_match_tgt1'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'data' was not located in columns for table 'esg_match_tgt1'
#   metadata.reflect(self._engine)
# 2022-07-17 18:46:58,602 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:46:58,605 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:46:58,606 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00107s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:46:59,772 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:46:59,773 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00123s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:47:01,159 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:47:01,160 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00127s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:47:02,338 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:47:02,339 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00116s] ('esg_matching', 'esg_match_ref$partitions')
# 2022-07-17 18:47:03,700 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_ref$properties"
# 2022-07-17 18:47:03,701 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00068s] ()
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'record_count' was not located in columns for table 'esg_match_ref'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'file_count' was not located in columns for table 'esg_match_ref'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'total_size' was not located in columns for table 'esg_match_ref'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'data' was not located in columns for table 'esg_match_ref'
#   metadata.reflect(self._engine)
# 2022-07-17 18:47:04,002 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:47:04,003 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:47:04,004 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00070s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:47:05,187 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:47:05,188 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00118s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:47:06,561 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:47:06,562 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00103s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:47:07,773 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:47:07,774 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00121s] ('esg_matching', 'esg_matching$partitions')
# 2022-07-17 18:47:09,593 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_matching$properties"
# 2022-07-17 18:47:09,593 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00081s] ()
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'record_count' was not located in columns for table 'esg_matching'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'file_count' was not located in columns for table 'esg_matching'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'total_size' was not located in columns for table 'esg_matching'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'data' was not located in columns for table 'esg_matching'
#   metadata.reflect(self._engine)
# 2022-07-17 18:47:09,890 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:47:09,892 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:47:09,892 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00075s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:47:11,101 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:47:11,101 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00090s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:47:12,483 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:47:12,484 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00160s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:47:13,672 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:47:13,673 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00108s] ('esg_matching', 'esg_no_matching$partitions')
# 2022-07-17 18:47:15,048 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_no_matching$properties"
# 2022-07-17 18:47:15,049 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00069s] ()
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'record_count' was not located in columns for table 'esg_no_matching'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'file_count' was not located in columns for table 'esg_no_matching'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'total_size' was not located in columns for table 'esg_no_matching'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'data' was not located in columns for table 'esg_no_matching'
#   metadata.reflect(self._engine)
# 2022-07-17 18:47:15,342 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:47:15,343 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:47:15,344 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00115s] ('esg_matching', 'matching')
# 2022-07-17 18:47:16,518 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:47:16,519 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00076s] ('esg_matching', 'matching')
# 2022-07-17 18:47:17,885 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:47:17,886 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00069s] ('esg_matching', 'matching')
# 2022-07-17 18:47:19,056 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:47:19,057 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00070s] ('esg_matching', 'matching$partitions')
# 2022-07-17 18:47:20,420 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."matching$properties"
# 2022-07-17 18:47:20,421 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00064s] ()
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'record_count' was not located in columns for table 'matching'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'file_count' was not located in columns for table 'matching'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'total_size' was not located in columns for table 'matching'
#   metadata.reflect(self._engine)
# C:\Users\Patrycia\OneDrive\Projects\GitHub\os_climate\esg-matching\notebooks\How-to guide\Perform exact matching\../../..\esg_matching\engine\connectors\base_connector.py:354: SAWarning: index key 'data' was not located in columns for table 'matching'
#   metadata.reflect(self._engine)
# 2022-07-17 18:47:20,719 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:47:20,719 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-17 18:47:20,721 INFO sqlalchemy.engine.Engine
# DROP TABLE esg_matching.esg_match_ref
# 2022-07-17 18:47:20,721 INFO sqlalchemy.engine.Engine [no key 0.00105s] ()
# 2022-07-17 18:47:23,472 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-17 18:47:23,474 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-17 18:47:23,476 INFO sqlalchemy.engine.Engine
# CREATE TABLE esg_matching.esg_match_ref (
# 	unique_id VARCHAR,
# 	isin VARCHAR(12),
# 	company VARCHAR(100),
# 	country VARCHAR(100)
# )
#
#
# 2022-07-17 18:47:23,477 INFO sqlalchemy.engine.Engine [no key 0.00119s] ()
# 2022-07-17 18:47:24,602 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '1', 'isin': 'SK1120005824', 'company': 'CENTRAL PERK', 'country': 'SK'}
# 2022-07-17 18:47:24,605 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_ref (unique_id, isin, company, country) VALUES (?, ?, ?, ?)
# 2022-07-17 18:47:24,606 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00129s] ('1', 'SK1120005824', 'CENTRAL PERK', 'SK')
# 2022-07-17 18:47:26,285 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '2', 'isin': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'company': 'HONEYDUKES', 'country': 'UNITED STATES OF AMERICA'}
# 2022-07-17 18:47:26,287 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_ref (unique_id, isin, company, country) VALUES (?, NULL, ?, ?)
# 2022-07-17 18:47:26,288 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00082s] ('2', 'HONEYDUKES', 'UNITED STATES OF AMERICA')
# 2022-07-17 18:47:28,062 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '3', 'isin': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'company': 'STARCOURT MALL', 'country': 'AUSTRIA'}
# 2022-07-17 18:47:28,064 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_ref (unique_id, isin, company, country) VALUES (?, NULL, ?, ?)
# 2022-07-17 18:47:28,065 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00130s] ('3', 'STARCOURT MALL', 'AUSTRIA')
# 2022-07-17 18:47:29,745 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '4', 'isin': 'GB00B1YW4409', 'company': 'STERLING COOPER', 'country': 'GBR'}
# 2022-07-17 18:47:29,746 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_ref (unique_id, isin, company, country) VALUES (?, ?, ?, ?)
# 2022-07-17 18:47:29,747 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00095s] ('4', 'GB00B1YW4409', 'STERLING COOPER', 'GBR')
# 2022-07-17 18:47:31,383 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '5', 'isin': 'CH0012221716', 'company': 'Bluth company', 'country': 'CHE'}
# 2022-07-17 18:47:31,384 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_ref (unique_id, isin, company, country) VALUES (?, ?, ?, ?)
# 2022-07-17 18:47:31,385 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00082s] ('5', 'CH0012221716', 'Bluth company', 'CHE')
# 2022-07-17 18:47:33,046 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '6', 'isin': 'US0200021014', 'company': 'InGen', 'country': 'usa'}
# 2022-07-17 18:47:33,048 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_ref (unique_id, isin, company, country) VALUES (?, ?, ?, ?)
# 2022-07-17 18:47:33,049 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00098s] ('6', 'US0200021014', 'InGen', 'usa')
# 2022-07-17 18:47:34,705 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '7', 'isin': 'US0231351067', 'company': 'Stark Industries', 'country': 'us'}
# 2022-07-17 18:47:34,706 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_ref (unique_id, isin, company, country) VALUES (?, ?, ?, ?)
# 2022-07-17 18:47:34,707 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00074s] ('7', 'US0231351067', 'Stark Industries', 'us')
# 2022-07-17 18:47:36,338 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '8', 'isin': 'US0126531013', 'company': 'SPECTRE', 'country': 'USA'}
# 2022-07-17 18:47:36,339 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_ref (unique_id, isin, company, country) VALUES (?, ?, ?, ?)
# 2022-07-17 18:47:36,340 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00110s] ('8', 'US0126531013', 'SPECTRE', 'USA')
# 2022-07-17 18:47:37,991 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '9', 'isin': 'US0126531013', 'company': 'SPECTRE 33 SUBSIDIARY', 'country': 'USA'}
# 2022-07-17 18:47:37,993 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_ref (unique_id, isin, company, country) VALUES (?, ?, ?, ?)
# 2022-07-17 18:47:37,994 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00065s] ('9', 'US0126531013', 'SPECTRE 33 SUBSIDIARY', 'USA')
# 2022-07-17 18:47:39,668 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Target Data Sources
tgt1_settings = '../../../tests/data/howto/trino/test_target1_trino.json'
tgt1_obj = File(tgt1_settings)

# %%
# Load data from TARGET 1
db_tgt1 = etl_proc_obj.load_file_to_db(tgt1_obj, csv_reader_obj)
# Out:
# 2022-07-17 18:47:39,701 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
# 2022-07-17 18:47:39,702 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00127s] ('esg_matching',)
# 2022-07-17 18:47:41,079 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
# 2022-07-17 18:47:41,080 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00099s] ('esg_matching',)
# 2022-07-17 18:47:42,451 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:47:42,452 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00149s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:47:43,620 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:47:43,621 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00099s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:47:45,004 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:47:45,006 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00129s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:47:46,181 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:47:46,182 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00068s] ('esg_matching', 'esg_match_tgt2$partitions')
# 2022-07-17 18:47:47,553 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_tgt2$properties"
# 2022-07-17 18:47:47,554 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00076s] ()
# 2022-07-17 18:47:47,848 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:47:47,849 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:47:47,849 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00075s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:47:49,031 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:47:49,032 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00070s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:47:50,410 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:47:50,411 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00073s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:47:51,581 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:47:51,582 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00097s] ('esg_matching', 'esg_match_tgt1$partitions')
# 2022-07-17 18:47:52,975 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_tgt1$properties"
# 2022-07-17 18:47:52,976 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00075s] ()
# 2022-07-17 18:47:53,271 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:47:53,272 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:47:53,274 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00120s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:47:54,447 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:47:54,448 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00078s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:47:55,806 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:47:55,807 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00085s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:47:56,985 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:47:56,986 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00098s] ('esg_matching', 'esg_match_ref$partitions')
# 2022-07-17 18:47:58,365 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_ref$properties"
# 2022-07-17 18:47:58,366 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00077s] ()
# 2022-07-17 18:47:58,659 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:47:58,661 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:47:58,661 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00121s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:47:59,830 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:47:59,831 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00126s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:48:01,226 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:01,227 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00084s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:48:02,418 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:48:02,419 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00141s] ('esg_matching', 'esg_matching$partitions')
# 2022-07-17 18:48:03,829 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_matching$properties"
# 2022-07-17 18:48:03,830 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00081s] ()
# 2022-07-17 18:48:04,127 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:48:04,128 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:04,129 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00065s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:48:05,302 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:48:05,303 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00092s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:48:06,666 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:06,667 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00083s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:48:07,835 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:48:07,835 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00087s] ('esg_matching', 'esg_no_matching$partitions')
# 2022-07-17 18:48:09,542 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_no_matching$properties"
# 2022-07-17 18:48:09,543 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00123s] ()
# 2022-07-17 18:48:09,838 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:48:09,840 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:09,840 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00089s] ('esg_matching', 'matching')
# 2022-07-17 18:48:11,052 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:48:11,053 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00097s] ('esg_matching', 'matching')
# 2022-07-17 18:48:12,447 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:12,448 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00110s] ('esg_matching', 'matching')
# 2022-07-17 18:48:13,631 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:48:13,632 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00132s] ('esg_matching', 'matching$partitions')
# 2022-07-17 18:48:15,321 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."matching$properties"
# 2022-07-17 18:48:15,322 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00114s] ()
# 2022-07-17 18:48:15,621 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:48:15,622 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-17 18:48:15,623 INFO sqlalchemy.engine.Engine
# DROP TABLE esg_matching.esg_match_tgt1
# 2022-07-17 18:48:15,624 INFO sqlalchemy.engine.Engine [no key 0.00106s] ()
# 2022-07-17 18:48:18,212 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-17 18:48:18,214 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-17 18:48:18,215 INFO sqlalchemy.engine.Engine
# CREATE TABLE esg_matching.esg_match_tgt1 (
# 	unique_id VARCHAR,
# 	isin VARCHAR(12),
# 	lei VARCHAR(20),
# 	company VARCHAR(255),
# 	country VARCHAR(255)
# )
#
#
# 2022-07-17 18:48:18,216 INFO sqlalchemy.engine.Engine [no key 0.00117s] ()
# 2022-07-17 18:48:19,262 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '1', 'isin': 'SK1120005824', 'lei': '097900BHK10000084115', 'company': 'CENTRAL PERK AND SONS', 'country': 'DE'}
# 2022-07-17 18:48:19,266 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt1 (unique_id, isin, lei, company, country) VALUES (?, ?, ?, ?, ?)
# 2022-07-17 18:48:19,267 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00110s] ('1', 'SK1120005824', '097900BHK10000084115', 'CENTRAL PERK AND SONS', 'DE')
# 2022-07-17 18:48:20,877 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '2', 'isin': 'DE0005545503', 'lei': '5299003VKVDCUPSS5X23', 'company': 'DUNDER MIFFLINS [12345]', 'country': 'de'}
# 2022-07-17 18:48:20,880 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt1 (unique_id, isin, lei, company, country) VALUES (?, ?, ?, ?, ?)
# 2022-07-17 18:48:20,882 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00234s] ('2', 'DE0005545503', '5299003VKVDCUPSS5X23', 'DUNDER MIFFLINS [12345]', 'de')
# 2022-07-17 18:48:22,461 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '3', 'isin': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'lei': '254900B1P3S786KDAW57', 'company': 'HONEYDUKES (adm@honeydukes.com)', 'country': 'UNITED STATES OF AMERICA'}
# 2022-07-17 18:48:22,464 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt1 (unique_id, isin, lei, company, country) VALUES (?, NULL, ?, ?, ?)
# 2022-07-17 18:48:22,465 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00176s] ('3', '254900B1P3S786KDAW57', 'HONEYDUKES (adm@honeydukes.com)', 'UNITED STATES OF AMERICA')
# 2022-07-17 18:48:24,064 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '4', 'isin': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'lei': '529900MVZ2YHFZV3K546', 'company': 'STARCOURT MALL', 'country': 'AUSTRIA'}
# 2022-07-17 18:48:24,066 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt1 (unique_id, isin, lei, company, country) VALUES (?, NULL, ?, ?, ?)
# 2022-07-17 18:48:24,067 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00127s] ('4', '529900MVZ2YHFZV3K546', 'STARCOURT MALL', 'AUSTRIA')
# 2022-07-17 18:48:25,631 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '5', 'isin': 'GB00B1YW4409', 'lei': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'company': 'Krusty Krab', 'country': 'GB'}
# 2022-07-17 18:48:25,633 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt1 (unique_id, isin, lei, company, country) VALUES (?, ?, NULL, ?, ?)
# 2022-07-17 18:48:25,634 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00094s] ('5', 'GB00B1YW4409', 'Krusty Krab', 'GB')
# 2022-07-17 18:48:27,249 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '6', 'isin': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'lei': '3003007MR0P683GYR674', 'company': 'RR DINER', 'country': 'CHINA'}
# 2022-07-17 18:48:27,252 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt1 (unique_id, isin, lei, company, country) VALUES (?, NULL, ?, ?, ?)
# 2022-07-17 18:48:27,252 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00093s] ('6', '3003007MR0P683GYR674', 'RR DINER', 'CHINA')
# 2022-07-17 18:48:28,907 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '7', 'isin': 'US0231351067', 'lei': 'ZXTILKJKG63JELOEG630', 'company': 'Starks Industries and Association', 'country': 'usa'}
# 2022-07-17 18:48:28,908 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt1 (unique_id, isin, lei, company, country) VALUES (?, ?, ?, ?, ?)
# 2022-07-17 18:48:28,909 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00098s] ('7', 'US0231351067', 'ZXTILKJKG63JELOEG630', 'Starks Industries and Association', 'usa')
# 2022-07-17 18:48:30,558 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '8', 'isin': 'US0126531013', 'lei': 'HDBLS2Q6GV1LSKQPBS54', 'company': 'SPECTRE UNIVERSAL LIMITED', 'country': 'USA'}
# 2022-07-17 18:48:30,560 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt1 (unique_id, isin, lei, company, country) VALUES (?, ?, ?, ?, ?)
# 2022-07-17 18:48:30,561 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00097s] ('8', 'US0126531013', 'HDBLS2Q6GV1LSKQPBS54', 'SPECTRE UNIVERSAL LIMITED', 'USA')
# 2022-07-17 18:48:32,176 INFO sqlalchemy.engine.Engine COMMIT

# %%
db_tgt1.get_policy_definition()
# Out:
# {'matching_with_ref1': {'dfm': {'isin': ['isin']},
#   'drm': {'name+country': ['company', 'country']},
#   'irm': {'isin': ['isin'],
#    'lei': ['lei'],
#    'name+country': ['company', 'country']}}}

# %%
# Target Data Sources
tgt2_settings = '../../../tests/data/howto/trino/test_target2_trino.json'
tgt2_obj = File(tgt2_settings)

# %%
# Load data from TARGET 1
db_tgt2 = etl_proc_obj.load_file_to_db(tgt2_obj, csv_reader_obj)
# Out:
# 2022-07-17 18:48:32,267 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
# 2022-07-17 18:48:32,269 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00165s] ('esg_matching',)
# 2022-07-17 18:48:33,648 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
# 2022-07-17 18:48:33,649 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00099s] ('esg_matching',)
# 2022-07-17 18:48:35,013 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:35,014 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00121s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:48:36,177 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:48:36,178 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00119s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:48:37,544 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:37,545 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00068s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:48:38,714 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:48:38,715 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00108s] ('esg_matching', 'esg_match_tgt2$partitions')
# 2022-07-17 18:48:40,080 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_tgt2$properties"
# 2022-07-17 18:48:40,081 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00093s] ()
# 2022-07-17 18:48:40,374 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:48:40,375 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:40,376 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00084s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:48:41,546 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:48:41,546 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00079s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:48:42,934 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:42,935 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00098s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:48:44,104 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:48:44,104 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00068s] ('esg_matching', 'esg_match_ref$partitions')
# 2022-07-17 18:48:45,462 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_ref$properties"
# 2022-07-17 18:48:45,464 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00315s] ()
# 2022-07-17 18:48:45,753 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:48:45,756 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:45,757 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00100s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:48:46,921 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:48:46,922 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00125s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:48:48,282 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:48,284 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00134s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:48:49,455 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:48:49,457 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00129s] ('esg_matching', 'esg_match_tgt1$partitions')
# 2022-07-17 18:48:50,813 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_tgt1$properties"
# 2022-07-17 18:48:50,813 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00074s] ()
# 2022-07-17 18:48:51,108 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:48:51,110 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:51,111 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00105s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:48:52,271 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:48:52,272 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00075s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:48:53,633 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:53,634 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00101s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:48:54,795 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:48:54,796 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00071s] ('esg_matching', 'esg_matching$partitions')
# 2022-07-17 18:48:56,152 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_matching$properties"
# 2022-07-17 18:48:56,153 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00071s] ()
# 2022-07-17 18:48:56,448 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:48:56,450 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:56,450 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00063s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:48:57,611 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:48:57,613 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00134s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:48:58,988 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:48:58,989 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00236s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:49:00,160 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:00,161 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00124s] ('esg_matching', 'esg_no_matching$partitions')
# 2022-07-17 18:49:01,532 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_no_matching$properties"
# 2022-07-17 18:49:01,533 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00073s] ()
# 2022-07-17 18:49:01,824 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:49:01,826 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:49:01,827 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00121s] ('esg_matching', 'matching')
# 2022-07-17 18:49:02,918 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:02,919 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00078s] ('esg_matching', 'matching')
# 2022-07-17 18:49:04,279 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:49:04,280 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00141s] ('esg_matching', 'matching')
# 2022-07-17 18:49:05,455 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:05,456 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00090s] ('esg_matching', 'matching$partitions')
# 2022-07-17 18:49:06,811 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."matching$properties"
# 2022-07-17 18:49:06,812 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00103s] ()
# 2022-07-17 18:49:07,102 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:49:07,104 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-17 18:49:07,105 INFO sqlalchemy.engine.Engine
# DROP TABLE esg_matching.esg_match_tgt2
# 2022-07-17 18:49:07,105 INFO sqlalchemy.engine.Engine [no key 0.00059s] ()
# 2022-07-17 18:49:09,587 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-17 18:49:09,589 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-17 18:49:09,591 INFO sqlalchemy.engine.Engine
# CREATE TABLE esg_matching.esg_match_tgt2 (
# 	unique_id VARCHAR,
# 	isin VARCHAR(12),
# 	lei VARCHAR(20),
# 	sedol VARCHAR(20),
# 	company VARCHAR(100),
# 	country VARCHAR(100)
# )
#
#
# 2022-07-17 18:49:09,592 INFO sqlalchemy.engine.Engine [no key 0.00091s] ()
# 2022-07-17 18:49:10,681 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '1', 'isin': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'lei': '097900BHK10000084115', 'sedol': '7108899', 'company': 'HONEYDUKES', 'country': 'UNITED STATES'}
# 2022-07-17 18:49:10,685 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt2 (unique_id, isin, lei, sedol, company, country) VALUES (?, NULL, ?, ?, ?, ?)
# 2022-07-17 18:49:10,686 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00116s] ('1', '097900BHK10000084115', '7108899', 'HONEYDUKES', 'UNITED STATES')
# 2022-07-17 18:49:12,370 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '2', 'isin': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'lei': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'sedol': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'company': 'STARCOURT MALL', 'country': 'AUSTRIA'}
# 2022-07-17 18:49:12,371 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt2 (unique_id, isin, lei, sedol, company, country) VALUES (?, NULL, NULL, NULL, ?, ?)
# 2022-07-17 18:49:12,373 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00157s] ('2', 'STARCOURT MALL', 'AUSTRIA')
# 2022-07-17 18:49:14,040 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '3', 'isin': 'CH0012221716', 'lei': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'sedol': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'company': 'Bluth company', 'country': 'CHE'}
# 2022-07-17 18:49:14,042 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt2 (unique_id, isin, lei, sedol, company, country) VALUES (?, ?, NULL, NULL, ?, ?)
# 2022-07-17 18:49:14,043 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00117s] ('3', 'CH0012221716', 'Bluth company', 'CHE')
# 2022-07-17 18:49:15,753 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '4', 'isin': 'US0200021014', 'lei': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'sedol': '2019952', 'company': 'InGen', 'country': 'usa'}
# 2022-07-17 18:49:15,754 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt2 (unique_id, isin, lei, sedol, company, country) VALUES (?, ?, NULL, ?, ?, ?)
# 2022-07-17 18:49:15,755 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00089s] ('4', 'US0200021014', '2019952', 'InGen', 'usa')
# 2022-07-17 18:49:17,524 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '5', 'isin': 'US0126531013', 'lei': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'sedol': '2046853', 'company': 'SPECTRE', 'country': 'USA'}
# 2022-07-17 18:49:17,526 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt2 (unique_id, isin, lei, sedol, company, country) VALUES (?, ?, NULL, ?, ?, ?)
# 2022-07-17 18:49:17,527 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00152s] ('5', 'US0126531013', '2046853', 'SPECTRE', 'USA')
# 2022-07-17 18:49:19,228 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '6', 'isin': 'GB00B1YW4409', 'lei': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'sedol': 'B1YW440', 'company': 'STERLING COOPER', 'country': 'GBR'}
# 2022-07-17 18:49:19,230 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt2 (unique_id, isin, lei, sedol, company, country) VALUES (?, ?, NULL, ?, ?, ?)
# 2022-07-17 18:49:19,231 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00087s] ('6', 'GB00B1YW4409', 'B1YW440', 'STERLING COOPER', 'GBR')
# 2022-07-17 18:49:20,940 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '7', 'isin': 'SK1120005824', 'lei': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'sedol': 'B1YW440', 'company': 'CENTRAL PERK', 'country': 'SK'}
# 2022-07-17 18:49:20,941 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt2 (unique_id, isin, lei, sedol, company, country) VALUES (?, ?, NULL, ?, ?, ?)
# 2022-07-17 18:49:20,942 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00118s] ('7', 'SK1120005824', 'B1YW440', 'CENTRAL PERK', 'SK')
# 2022-07-17 18:49:22,603 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '8', 'isin': 'DE0005545503', 'lei': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'sedol': '5299003VKVDCUPSS5X23', 'company': 'DUNDER MIFFLINS', 'country': 'Germany'}
# 2022-07-17 18:49:22,604 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt2 (unique_id, isin, lei, sedol, company, country) VALUES (?, ?, NULL, ?, ?, ?)
# 2022-07-17 18:49:22,606 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00163s] ('8', 'DE0005545503', '5299003VKVDCUPSS5X23', 'DUNDER MIFFLINS', 'Germany')
# 2022-07-17 18:49:24,212 INFO sqlalchemy.engine.Engine COMMIT
# {'unique_id': '9', 'isin': 'GB00B1YW4409', 'lei': <sqlalchemy.sql.elements.Null object at 0x00000204E963EAC0>, 'sedol': 'B1YW440', 'company': 'Krusty Kr~ab', 'country': 'GBR'}
# 2022-07-17 18:49:24,214 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_match_tgt2 (unique_id, isin, lei, sedol, company, country) VALUES (?, ?, NULL, ?, ?, ?)
# 2022-07-17 18:49:24,215 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00080s] ('9', 'GB00B1YW4409', 'B1YW440', 'Krusty Kr~ab', 'GBR')
# 2022-07-17 18:49:25,864 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## 3. Creating matching/no-matching tables

# %%
match_settings = '../../../tests/data/howto/trino/test_matching_trino.json'
no_match_settings = '../../../tests/data/howto/trino/test_no_matching_trino.json'

# %%
file_match = File(match_settings)
file_no_match = File(no_match_settings)

# %%
# Call the create_data_source_from_settings() method by passing the File
db_matching = etl_proc_obj.create_data_source(file_match)
# Out:
# 2022-07-17 18:49:25,924 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
# 2022-07-17 18:49:25,925 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00110s] ('esg_matching',)
# 2022-07-17 18:49:27,277 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
# 2022-07-17 18:49:27,278 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00077s] ('esg_matching',)
# 2022-07-17 18:49:28,642 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:49:28,642 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00068s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:49:29,808 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:29,809 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00082s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:49:31,157 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:49:31,158 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00106s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:49:32,315 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:32,316 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00133s] ('esg_matching', 'esg_match_tgt2$partitions')
# 2022-07-17 18:49:33,671 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_tgt2$properties"
# 2022-07-17 18:49:33,672 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00074s] ()
# 2022-07-17 18:49:33,968 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:49:33,969 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:49:33,969 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00074s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:49:35,138 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:35,139 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00078s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:49:36,507 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:49:36,508 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00113s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:49:37,685 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:37,686 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00093s] ('esg_matching', 'esg_match_ref$partitions')
# 2022-07-17 18:49:39,053 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_ref$properties"
# 2022-07-17 18:49:39,054 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00067s] ()
# 2022-07-17 18:49:39,344 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:49:39,346 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:49:39,347 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00097s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:49:40,508 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:40,509 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00123s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:49:41,875 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:49:41,876 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00165s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:49:43,046 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:43,047 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00168s] ('esg_matching', 'esg_match_tgt1$partitions')
# 2022-07-17 18:49:44,403 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_tgt1$properties"
# 2022-07-17 18:49:44,404 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00068s] ()
# 2022-07-17 18:49:44,696 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:49:44,697 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:49:44,698 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00072s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:49:45,869 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:45,870 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00099s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:49:47,232 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:49:47,233 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00076s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:49:48,392 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:48,393 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00076s] ('esg_matching', 'esg_matching$partitions')
# 2022-07-17 18:49:49,760 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_matching$properties"
# 2022-07-17 18:49:49,761 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00073s] ()
# 2022-07-17 18:49:50,053 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:49:50,055 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:49:50,056 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00106s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:49:51,218 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:51,218 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00076s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:49:52,578 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:49:52,579 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00168s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:49:53,753 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:53,754 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00070s] ('esg_matching', 'esg_no_matching$partitions')
# 2022-07-17 18:49:55,115 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_no_matching$properties"
# 2022-07-17 18:49:55,116 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00113s] ()
# 2022-07-17 18:49:55,412 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:49:55,414 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:49:55,415 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00151s] ('esg_matching', 'matching')
# 2022-07-17 18:49:56,589 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:56,590 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00094s] ('esg_matching', 'matching')
# 2022-07-17 18:49:57,959 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:49:57,961 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00124s] ('esg_matching', 'matching')
# 2022-07-17 18:49:59,139 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:49:59,140 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00121s] ('esg_matching', 'matching$partitions')
# 2022-07-17 18:50:00,527 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."matching$properties"
# 2022-07-17 18:50:00,528 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00114s] ()
# 2022-07-17 18:50:00,825 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:50:00,826 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-17 18:50:00,827 INFO sqlalchemy.engine.Engine
# DROP TABLE esg_matching.esg_matching
# 2022-07-17 18:50:00,828 INFO sqlalchemy.engine.Engine [no key 0.00125s] ()
# 2022-07-17 18:50:01,394 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-17 18:50:01,397 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-17 18:50:01,399 INFO sqlalchemy.engine.Engine
# CREATE TABLE esg_matching.esg_matching (
# 	matching_id INTEGER,
# 	ref_name VARCHAR,
# 	tgt_name VARCHAR,
# 	matching_type VARCHAR,
# 	matching_scope VARCHAR,
# 	matching_rule VARCHAR,
# 	ref_id VARCHAR,
# 	ref_company VARCHAR,
# 	ref_country VARCHAR,
# 	tgt_id VARCHAR,
# 	tgt_company VARCHAR,
# 	tgt_country VARCHAR,
# 	isin VARCHAR,
# 	lei VARCHAR,
# 	sedol VARCHAR
# )
#
#
# 2022-07-17 18:50:01,400 INFO sqlalchemy.engine.Engine [no key 0.00105s] ()
# 2022-07-17 18:50:02,451 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Call the create_data_source_from_settings() method by passing the File
db_no_matching = etl_proc_obj.create_data_source(file_no_match)
# Out:
# 2022-07-17 18:50:02,462 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
# 2022-07-17 18:50:02,463 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00188s] ('esg_matching',)
# 2022-07-17 18:50:03,849 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
# 2022-07-17 18:50:03,850 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00114s] ('esg_matching',)
# 2022-07-17 18:50:05,227 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:50:05,228 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00108s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:50:06,405 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:50:06,406 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00081s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:50:07,778 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:50:07,779 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00071s] ('esg_matching', 'esg_match_tgt2')
# 2022-07-17 18:50:08,961 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:50:08,962 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00125s] ('esg_matching', 'esg_match_tgt2$partitions')
# 2022-07-17 18:50:10,328 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_tgt2$properties"
# 2022-07-17 18:50:10,329 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00070s] ()
# 2022-07-17 18:50:10,625 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:50:10,627 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:50:10,628 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00163s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:50:11,805 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:50:11,806 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00138s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:50:13,189 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:50:13,190 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00104s] ('esg_matching', 'esg_match_ref')
# 2022-07-17 18:50:14,354 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:50:14,355 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00113s] ('esg_matching', 'esg_match_ref$partitions')
# 2022-07-17 18:50:15,715 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_ref$properties"
# 2022-07-17 18:50:15,715 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00074s] ()
# 2022-07-17 18:50:16,013 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:50:16,014 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:50:16,015 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00074s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:50:17,193 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:50:17,193 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00070s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:50:18,554 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:50:18,555 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00115s] ('esg_matching', 'esg_match_tgt1')
# 2022-07-17 18:50:19,720 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:50:19,722 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00145s] ('esg_matching', 'esg_match_tgt1$partitions')
# 2022-07-17 18:50:21,083 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_match_tgt1$properties"
# 2022-07-17 18:50:21,084 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00107s] ()
# 2022-07-17 18:50:21,381 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:50:21,382 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:50:21,382 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00074s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:50:22,579 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:50:22,580 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00081s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:50:23,936 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:50:23,936 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00071s] ('esg_matching', 'esg_matching')
# 2022-07-17 18:50:25,105 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:50:25,106 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00123s] ('esg_matching', 'esg_matching$partitions')
# 2022-07-17 18:50:26,464 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_matching$properties"
# 2022-07-17 18:50:26,465 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00111s] ()
# 2022-07-17 18:50:26,758 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:50:26,759 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:50:26,760 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00106s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:50:27,925 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:50:27,926 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00106s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:50:29,352 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:50:29,352 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00075s] ('esg_matching', 'esg_no_matching')
# 2022-07-17 18:50:30,514 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:50:30,515 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00109s] ('esg_matching', 'esg_no_matching$partitions')
# 2022-07-17 18:50:31,872 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."esg_no_matching$properties"
# 2022-07-17 18:50:31,872 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00108s] ()
# 2022-07-17 18:50:32,168 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:50:32,170 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:50:32,170 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00073s] ('esg_matching', 'matching')
# 2022-07-17 18:50:33,329 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:50:33,330 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00115s] ('esg_matching', 'matching')
# 2022-07-17 18:50:34,706 INFO sqlalchemy.engine.Engine SELECT "table_name"
# FROM "information_schema"."tables"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# 2022-07-17 18:50:34,707 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00095s] ('esg_matching', 'matching')
# 2022-07-17 18:50:35,878 INFO sqlalchemy.engine.Engine SELECT
#     "column_name",
#     "data_type",
#     "column_default",
#     UPPER("is_nullable") AS "is_nullable"
# FROM "information_schema"."columns"
# WHERE "table_schema" = ?
#   AND "table_name" = ?
# ORDER BY "ordinal_position" ASC
# 2022-07-17 18:50:35,879 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00101s] ('esg_matching', 'matching$partitions')
# 2022-07-17 18:50:37,151 INFO sqlalchemy.engine.Engine SELECT "comment" FROM "esg_matching"."matching$properties"
# 2022-07-17 18:50:37,153 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00232s] ()
# 2022-07-17 18:50:37,452 INFO sqlalchemy.engine.Engine ROLLBACK
# 2022-07-17 18:50:37,453 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-17 18:50:37,454 INFO sqlalchemy.engine.Engine
# DROP TABLE esg_matching.esg_no_matching
# 2022-07-17 18:50:37,455 INFO sqlalchemy.engine.Engine [no key 0.00118s] ()
# 2022-07-17 18:50:38,625 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-17 18:50:38,626 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-17 18:50:38,628 INFO sqlalchemy.engine.Engine
# CREATE TABLE esg_matching.esg_no_matching (
# 	matching_id INTEGER,
# 	tgt_name VARCHAR,
# 	tgt_id VARCHAR,
# 	tgt_company VARCHAR,
# 	tgt_country VARCHAR,
# 	isin VARCHAR,
# 	lei VARCHAR,
# 	sedol VARCHAR
# )
#
#
# 2022-07-17 18:50:38,629 INFO sqlalchemy.engine.Engine [no key 0.00129s] ()
# 2022-07-17 18:50:39,641 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## 4. Checking attribute mapping alias

# %%
db_ref.get_mapping_to_alias()
# Out:
# {'isin': Column('isin', String(length=12), table=<esg_match_ref>),
#  'company': Column('company', String(length=100), table=<esg_match_ref>),
#  'country': Column('country', String(length=100), table=<esg_match_ref>)}

# %%
db_tgt1.get_mapping_to_alias()
# Out:
# {'isin': Column('isin', String(length=12), table=<esg_match_tgt1>),
#  'lei': Column('lei', String(length=20), table=<esg_match_tgt1>),
#  'company': Column('company', String(length=255), table=<esg_match_tgt1>),
#  'country': Column('country', String(length=255), table=<esg_match_tgt1>)}

# %%
db_tgt2.get_mapping_to_alias()
# Out:
# {'isin': Column('isin', String(length=12), table=<esg_match_tgt2>),
#  'lei': Column('lei', String(length=20), table=<esg_match_tgt2>),
#  'sedol': Column('sedol', String(length=20), table=<esg_match_tgt2>),
#  'company': Column('company', String(length=100), table=<esg_match_tgt2>),
#  'country': Column('country', String(length=100), table=<esg_match_tgt2>)}

# %% [markdown]
# ## 5. Checking attribute mapping between sources and matching tables

# %%
db_ref.get_mapping_to_matching()
# Out:
# {'ref_id': Column('unique_id', String(), table=<esg_match_ref>),
#  'ref_company': Column('company', String(length=100), table=<esg_match_ref>),
#  'ref_country': Column('country', String(length=100), table=<esg_match_ref>)}

# %%
db_tgt1.get_mapping_to_matching()
# Out:
# {'tgt_id': Column('unique_id', String(), table=<esg_match_tgt1>),
#  'isin': Column('isin', String(length=12), table=<esg_match_tgt1>),
#  'lei': Column('lei', String(length=20), table=<esg_match_tgt1>),
#  'tgt_company': Column('company', String(length=255), table=<esg_match_tgt1>),
#  'tgt_country': Column('country', String(length=255), table=<esg_match_tgt1>)}

# %%
db_tgt2.get_mapping_to_matching()
# Out:
# {'tgt_id': Column('unique_id', String(), table=<esg_match_tgt2>),
#  'isin': Column('isin', String(length=12), table=<esg_match_tgt2>),
#  'lei': Column('lei', String(length=20), table=<esg_match_tgt2>),
#  'sedol': Column('sedol', String(length=20), table=<esg_match_tgt2>),
#  'tgt_company': Column('company', String(length=100), table=<esg_match_tgt2>),
#  'tgt_country': Column('country', String(length=100), table=<esg_match_tgt2>)}

# %% [markdown]
# ## 6. Create policies for matching each target data source with the referential

# %%
# Import policy module
from esg_matching.matcher.policy import MatchingPolicy

# %%
# Create macthing policy object for target1
policy_match_tgt1 = MatchingPolicy(db_tgt1, 'matching_with_ref1')

# %%
# Set the referential and matching/no-matching sources
policy_match_tgt1.set_referential_source(db_ref)
policy_match_tgt1.set_matching_source(db_matching)
policy_match_tgt1.set_no_matching_source(db_no_matching)

# %%
# Create macthing policy object for target2
policy_match_tgt2 = MatchingPolicy(db_tgt2, 'matching_with_ref1')

# %%
# Set the referential and matching/no-matching sources
policy_match_tgt2.set_referential_source(db_ref)
policy_match_tgt2.set_matching_source(db_matching)
policy_match_tgt2.set_no_matching_source(db_no_matching)

# %% [markdown]
# ## 7. Perform direct full matching (DFM) for each data source

# %%
# Import DFM module
from esg_matching.matcher.dfm import DbMatcherDfm

# %%
# Create a matcher object for DFM
dfm_matcher_obj = DbMatcherDfm(db_conn)

# %%
# Perform DFM on target 1
dfm_matcher_obj.set_policy(policy_match_tgt1)
dfm_matcher_obj.execute_matching()
# Out:
# 2022-07-17 18:50:40,010 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_matching (ref_name, tgt_name, matching_type, matching_scope, matching_rule, tgt_id, isin, lei, tgt_company, tgt_country, ref_id, ref_company, ref_country) SELECT 'ds_ref' AS ref_name, 'ds_tgt1' AS tgt_name, 'direct' AS matching_type, 'full' AS matching_scope, 'isin' AS matching_rule, esg_matching.esg_match_tgt1.unique_id AS tgt_id, esg_matching.esg_match_tgt1.isin AS isin, esg_matching.esg_match_tgt1.lei AS lei, esg_matching.esg_match_tgt1.company AS tgt_company, esg_matching.esg_match_tgt1.country AS tgt_country, esg_matching.esg_match_ref.unique_id AS ref_id, esg_matching.esg_match_ref.company AS ref_company, esg_matching.esg_match_ref.country AS ref_country
# FROM esg_matching.esg_match_tgt1 JOIN esg_matching.esg_match_ref ON esg_matching.esg_match_tgt1.isin = esg_matching.esg_match_ref.isin
# 2022-07-17 18:50:40,011 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00183s] ()
# 2022-07-17 18:50:43,833 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-17 18:50:43,835 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_no_matching (tgt_name, tgt_id, isin, lei, tgt_company, tgt_country) SELECT 'ds_tgt1' AS tgt_name, esg_matching.esg_match_tgt1.unique_id AS tgt_id, esg_matching.esg_match_tgt1.isin AS isin, esg_matching.esg_match_tgt1.lei AS lei, esg_matching.esg_match_tgt1.company AS tgt_company, esg_matching.esg_match_tgt1.country AS tgt_country
# FROM esg_matching.esg_match_tgt1 LEFT OUTER JOIN esg_matching.esg_match_ref ON esg_matching.esg_match_tgt1.isin = esg_matching.esg_match_ref.isin
# WHERE esg_matching.esg_match_ref.isin IS NULL
# 2022-07-17 18:50:43,836 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00130s] ()
# 2022-07-17 18:50:46,234 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Perform DFM on target 2
dfm_matcher_obj.set_policy(policy_match_tgt2)
dfm_matcher_obj.execute_matching()
# Out:
# 2022-07-17 18:50:46,258 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_matching (ref_name, tgt_name, matching_type, matching_scope, matching_rule, tgt_id, isin, lei, sedol, tgt_company, tgt_country, ref_id, ref_company, ref_country) SELECT 'ds_ref' AS ref_name, 'ds_tgt2' AS tgt_name, 'direct' AS matching_type, 'full' AS matching_scope, 'isin' AS matching_rule, esg_matching.esg_match_tgt2.unique_id AS tgt_id, esg_matching.esg_match_tgt2.isin AS isin, esg_matching.esg_match_tgt2.lei AS lei, esg_matching.esg_match_tgt2.sedol AS sedol, esg_matching.esg_match_tgt2.company AS tgt_company, esg_matching.esg_match_tgt2.country AS tgt_country, esg_matching.esg_match_ref.unique_id AS ref_id, esg_matching.esg_match_ref.company AS ref_company, esg_matching.esg_match_ref.country AS ref_country
# FROM esg_matching.esg_match_tgt2 JOIN esg_matching.esg_match_ref ON esg_matching.esg_match_tgt2.isin = esg_matching.esg_match_ref.isin
# 2022-07-17 18:50:46,260 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00174s] ()
# 2022-07-17 18:50:50,122 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-17 18:50:50,124 INFO sqlalchemy.engine.Engine INSERT INTO esg_matching.esg_no_matching (tgt_name, tgt_id, isin, lei, sedol, tgt_company, tgt_country) SELECT 'ds_tgt2' AS tgt_name, esg_matching.esg_match_tgt2.unique_id AS tgt_id, esg_matching.esg_match_tgt2.isin AS isin, esg_matching.esg_match_tgt2.lei AS lei, esg_matching.esg_match_tgt2.sedol AS sedol, esg_matching.esg_match_tgt2.company AS tgt_company, esg_matching.esg_match_tgt2.country AS tgt_country
# FROM esg_matching.esg_match_tgt2 LEFT OUTER JOIN esg_matching.esg_match_ref ON esg_matching.esg_match_tgt2.isin = esg_matching.esg_match_ref.isin
# WHERE esg_matching.esg_match_ref.isin IS NULL
# 2022-07-17 18:50:50,125 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00106s] ()
# 2022-07-17 18:50:52,450 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## 8. Perform direct residual matching (DRM) for each data source

# %%
# Import DRM module
from esg_matching.matcher.drm import DbMatcherDrm

# %%
# Create a matcher object for DRM
drm_matcher_obj = DbMatcherDrm(db_conn)

# %%
# Perform DRM on target 1
drm_matcher_obj.set_policy(policy_match_tgt1)
drm_matcher_obj.execute_matching()

# %%
# Perform DRM on target 2
drm_matcher_obj.set_policy(policy_match_tgt2)
drm_matcher_obj.execute_matching()

# %% [markdown]
# ## 9. Perform indirect residual matching (IRM) for each data source

# %%
# Import IFM module
from esg_matching.matcher.irm import DbMatcherIrm

# %%
# Create a matcher object for IFM
ifm_matcher_obj = DbMatcherIrm(db_conn)

# %%
# Perform IFM on target 1
ifm_matcher_obj.set_policy(policy_match_tgt1)
ifm_matcher_obj.execute_matching()

# %%
# Perform IFM on target 2
ifm_matcher_obj.set_policy(policy_match_tgt2)
ifm_matcher_obj.execute_matching()

# %% [markdown]
# ## 10. Retrieving the matching and no-matching tables

# %%
# Query the matching table
df_matching = db_matching.get_data_as_df()
df_matching
# Out:
# 2022-07-17 18:50:55,057 INFO sqlalchemy.engine.Engine SELECT esg_matching.esg_matching.matching_id, esg_matching.esg_matching.ref_name, esg_matching.esg_matching.tgt_name, esg_matching.esg_matching.matching_type, esg_matching.esg_matching.matching_scope, esg_matching.esg_matching.matching_rule, esg_matching.esg_matching.ref_id, esg_matching.esg_matching.ref_company, esg_matching.esg_matching.ref_country, esg_matching.esg_matching.tgt_id, esg_matching.esg_matching.tgt_company, esg_matching.esg_matching.tgt_country, esg_matching.esg_matching.isin, esg_matching.esg_matching.lei, esg_matching.esg_matching.sedol
# FROM esg_matching.esg_matching
# 2022-07-17 18:50:55,058 INFO sqlalchemy.engine.Engine [dialect trino+rest does not support caching 0.00126s] ()
#    matching_id ref_name tgt_name matching_type matching_scope matching_rule  \
# 0         None   ds_ref  ds_tgt2        direct           full          isin
# 1         None   ds_ref  ds_tgt2        direct           full          isin
# 2         None   ds_ref  ds_tgt2        direct           full          isin
# 3         None   ds_ref  ds_tgt2        direct           full          isin
# 4         None   ds_ref  ds_tgt2        direct           full          isin
# 5         None   ds_ref  ds_tgt2        direct           full          isin
# 6         None   ds_ref  ds_tgt2        direct           full          isin
# 7         None   ds_ref  ds_tgt1        direct           full          isin
# 8         None   ds_ref  ds_tgt1        direct           full          isin
# 9         None   ds_ref  ds_tgt1        direct           full          isin
# 10        None   ds_ref  ds_tgt1        direct           full          isin
# 11        None   ds_ref  ds_tgt1        direct           full          isin
#
#    ref_id            ref_company ref_country tgt_id  \
# 0       6                  InGen         usa      4
# 1       5          Bluth company         CHE      3
# 2       4        STERLING COOPER         GBR      6
# 3       4        STERLING COOPER         GBR      9
# 4       1           CENTRAL PERK          SK      7
# 5       9  SPECTRE 33 SUBSIDIARY         USA      5
# 6       8                SPECTRE         USA      5
# 7       4        STERLING COOPER         GBR      5
# 8       1           CENTRAL PERK          SK      1
# 9       9  SPECTRE 33 SUBSIDIARY         USA      8
# 10      8                SPECTRE         USA      8
# 11      7       Stark Industries          us      7
#
#                           tgt_company tgt_country          isin  \
# 0                               InGen         usa  US0200021014
# 1                       Bluth company         CHE  CH0012221716
# 2                     STERLING COOPER         GBR  GB00B1YW4409
# 3                        Krusty Kr~ab         GBR  GB00B1YW4409
# 4                        CENTRAL PERK          SK  SK1120005824
# 5                             SPECTRE         USA  US0126531013
# 6                             SPECTRE         USA  US0126531013
# 7                         Krusty Krab          GB  GB00B1YW4409
# 8               CENTRAL PERK AND SONS          DE  SK1120005824
# 9           SPECTRE UNIVERSAL LIMITED         USA  US0126531013
# 10          SPECTRE UNIVERSAL LIMITED         USA  US0126531013
# 11  Starks Industries and Association         usa  US0231351067
#
#                      lei    sedol
# 0                   None  2019952
# 1                   None     None
# 2                   None  B1YW440
# 3                   None  B1YW440
# 4                   None  B1YW440
# 5                   None  2046853
# 6                   None  2046853
# 7                   None     None
# 8   097900BHK10000084115     None
# 9   HDBLS2Q6GV1LSKQPBS54     None
# 10  HDBLS2Q6GV1LSKQPBS54     None
# 11  ZXTILKJKG63JELOEG630     None

# %%
# Query the no-matching table
df_no_matching = db_no_matching.get_data_as_df()
df_no_matching

# %% [markdown]
# ## 11. Close database connection

# %%
db_conn.disconnect()

# %%
db_conn.is_connected()
